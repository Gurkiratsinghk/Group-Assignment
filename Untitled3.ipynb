# %% [markdown]
# <a href="https://colab.research.google.com/github/Gurkiratsinghk/Group-Assignment/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Gurkiratsinghk/Group-Assignment.git
# Out:
# Cloning into 'Group-Assignment'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 39 (delta 2), reused 39 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 587.60 KiB | 4.52 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
